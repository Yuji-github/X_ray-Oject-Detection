# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
base_path = '../input/siim-covid19-detectionut'
for dirname, _, filenames in os.walk(base_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !conda install -c conda-forge gdcm -y # prevnding GDCM errors when exporting images
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdcm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gdcm-2.8.9                 |   py37h5d359c0_2         3.4 MB  conda-forge
#     libjpeg-turbo-2.1.0        |       h7f98852_0         987 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   gdcm               conda-forge/linux-64::gdcm-2.8.9-py37h5d359c0_2
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-2.1.0-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# libjpeg-turbo-2.1.0  | 987 KB    | ##################################### | 100%
# gdcm-2.8.9           | 3.4 MB    | ##################################### | 100%
# done
# done
# done

# %% [markdown]
# # Resizeing and Converting Imgaes

# %%
import pydicom
import scipy.misc
from pydicom import dcmread
from pydicom.data import get_testdata_file
import scipy.misc
from PIL import Image
import matplotlib.pyplot as plt
import glob
import cv2

# need to re-run once reload this note book
# !pip install pylibjpeg pylibjpeg-libjpeg pydicom # handling Pixel Data that hasn't been compressed as some dcm files give runtime errors
import pylibjpeg
# Out:
# Collecting pylibjpeg
#   Downloading pylibjpeg-1.3.0-py3-none-any.whl (28 kB)
# Collecting pylibjpeg-libjpeg
#   Downloading pylibjpeg_libjpeg-1.2.0-cp37-cp37m-manylinux2010_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 1.4 MB/s
# Requirement already satisfied: pydicom in /opt/conda/lib/python3.7/site-packages (2.1.2)
# Collecting pylibjpeg-rle
#   Downloading pylibjpeg_rle-1.1.0-cp37-cp37m-manylinux2010_x86_64.whl (884 kB)
#      |████████████████████████████████| 884 kB 9.2 MB/s
# Collecting pylibjpeg-openjpeg
#   Downloading pylibjpeg_openjpeg-1.1.1-cp37-cp37m-manylinux2010_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 9.7 MB/s
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pylibjpeg) (1.19.5)
# Installing collected packages: pylibjpeg-rle, pylibjpeg-openjpeg, pylibjpeg-libjpeg, pylibjpeg
# Successfully installed pylibjpeg-1.3.0 pylibjpeg-libjpeg-1.2.0 pylibjpeg-openjpeg-1.1.1 pylibjpeg-rle-1.1.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# # Gathering Path

# %%
trainimlist = []

for dirname, _, filenames in os.walk('../input/siim-covid19-detection/train'):
    for filename in filenames:
        trainimlist.append(os.path.join(dirname, filename))

# %% [markdown]
# # Create Save Path

# %%
# !mkdir "/kaggle/working/output"

# %%
image_size = pd.DataFrame(columns = ['id', 'ori_width', 'ori_height', 're_width', 're_height']) # to save resized image data

for pic in trainimlist:
    data = []
    # preparing save files 
    save_pic = pic.replace("../input/siim-covid19-detection/train", '')
    root = save_pic.split('/')
    save_root = '/kaggle/working/output/'+root[1]+'/'+root[2]+'/'
    
    if os.path.exists(save_root) == False: # some images have the same study_id (path)
        os.makedirs(save_root)    
    
    # reading images
    Input_Image = pydicom.dcmread(pic) # class type
    
    # can check meta-DCM data
    # print(Input_Image)
    
    img_height  = Input_Image.Rows
    img_width  = Input_Image.Columns
    
    Input_Image.PhotometricInterpretation = 'YBR_FULL' # handle GDCM and Pillow(for jpg, jpeg)
    img = Input_Image.pixel_array  # type is 2d np.array
    
    new_path = save_root + root[3].replace('.dcm','.jpg') # creating save file as jpg
    cv2.imwrite(new_path,img) # convert to jpg (ndarray)    
    
    img = (np.maximum(img, 0) / img.max())*255 # Normalize the image between 0 and 255 (colors)
    img.astype(np.uint8) # float values need to be int for the next step
    img_mem = Image.fromarray(img) # back to the image (cannot handle float values)
    img_mem = img_mem.convert("L") # L -> 8 bit : RGB -> 24 bits
   
    data.append(root[3].replace('.dcm','.jpg'))
    data.append(float(img_mem.size[0]))
    data.append(float(img_mem.size[1]))
    
    # resize image sizes as 416: keeping aspect ratio    
    fixed_size = 416 # modify this size 
    height_percent = (fixed_size / float(img_mem.size[1])) # img_mem.size[1] is height
    width_size = int((float(img_mem.size[0]) * float(height_percent)))
    img_mem = img_mem.resize((width_size, fixed_size), Image.NEAREST)
   
    # plt.imshow(img_mem)
    
    data.append(float(img_mem.size[0]))
    data.append(fixed_size)
    
    # saving the images as jpg
    img_mem.save(new_path)
    
    index = len(image_size) # geting index number to add                
    image_size.loc[index] = data # adding the row    
       

image_size.to_csv('/kaggle/working/image_size.csv',index=False)
print("Exported!!")
# Out:
# /opt/conda/lib/python3.7/site-packages/pydicom/pixel_data_handlers/numpy_handler.py:341: UserWarning: The length of the pixel data in the dataset (13262360 bytes) indicates it contains excess padding. 216296 bytes will be removed from the end of the data
#   warnings.warn(msg)
# Exported!!

# %% [markdown]
# # Exporting Multiple(Nested) Folders to the Local PC

# %%
# %%!
# zip -r output.zip /kaggle/working/output
# Out:
# ['  adding: kaggle/working/output/ (stored 0%)',
#  '  adding: kaggle/working/output/941bf7ac39f3/ (stored 0%)',
#  '  adding: kaggle/working/output/941bf7ac39f3/d2d12912b0e2/ (stored 0%)',
#  '  adding: kaggle/working/output/941bf7ac39f3/d2d12912b0e2/94c14ab04442.jpg (deflated 4%)',
#  '  adding: kaggle/working/output/e44d1faedace/ (stored 0%)',
#  '  adding: kaggle/working/output/e44d1faedace/0510868a6ed3/ (stored 0%)',
#  '  adding: kaggle/working/output/e44d1faedace/0510868a6ed3/8ffe76d2e1e7.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/32218484a1a6/ (stored 0%)',
#  '  adding: kaggle/working/output/32218484a1a6/92aa24b40061/ (stored 0%)',
#  '  adding: kaggle/working/output/32218484a1a6/92aa24b40061/0b4a60630af2.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/c6583ca18178/ (stored 0%)',
#  '  adding: kaggle/working/output/c6583ca18178/82be30f20872/ (stored 0%)',
#  '  adding: kaggle/working/output/c6583ca18178/82be30f20872/1700e25c3938.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/ded489f168bc/ (stored 0%)',
#  '  adding: kaggle/working/output/ded489f168bc/64ca4072b945/ (stored 0%)',
#  '  adding: kaggle/working/output/ded489f168bc/64ca4072b945/ee5b25fc720b.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/4ee4406b32a0/ (stored 0%)',
#  '  adding: kaggle/working/output/4ee4406b32a0/6419a349c520/ (stored 0%)',
#  '  adding: kaggle/working/output/4ee4406b32a0/6419a349c520/588ffbef2de4.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/5bcc368d5cf4/ (stored 0%)',
#  '  adding: kaggle/working/output/5bcc368d5cf4/cc854e46cd4d/ (stored 0%)',
#  '  adding: kaggle/working/output/5bcc368d5cf4/cc854e46cd4d/4d5364b334dd.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/db33e376f3ef/ (stored 0%)',
#  '  adding: kaggle/working/output/db33e376f3ef/6c239bb5975e/ (stored 0%)',
#  '  adding: kaggle/working/output/db33e376f3ef/6c239bb5975e/18c2fb2fb8d1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/698ec439ea71/ (stored 0%)',
#  '  adding: kaggle/working/output/698ec439ea71/e034f88e4342/ (stored 0%)',
#  '  adding: kaggle/working/output/698ec439ea71/e034f88e4342/9062f70a3dd7.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/349b1b80a237/ (stored 0%)',
#  '  adding: kaggle/working/output/349b1b80a237/f661a3aaab4a/ (stored 0%)',
#  '  adding: kaggle/working/output/349b1b80a237/f661a3aaab4a/e474328cb72e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/185dd4caeaa6/ (stored 0%)',
#  '  adding: kaggle/working/output/185dd4caeaa6/cb918526b9c9/ (stored 0%)',
#  '  adding: kaggle/working/output/185dd4caeaa6/cb918526b9c9/8b8af1943344.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/5062655a0c9f/ (stored 0%)',
#  '  adding: kaggle/working/output/5062655a0c9f/1d25e5b1885d/ (stored 0%)',
#  '  adding: kaggle/working/output/5062655a0c9f/1d25e5b1885d/aabc9640011b.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/8222875f1a91/ (stored 0%)',
#  '  adding: kaggle/working/output/8222875f1a91/fbbf6241fbfd/ (stored 0%)',
#  '  adding: kaggle/working/output/8222875f1a91/fbbf6241fbfd/4f3d52d652dd.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/6317840e9b47/ (stored 0%)',
#  '  adding: kaggle/working/output/6317840e9b47/b32fe50b981a/ (stored 0%)',
#  '  adding: kaggle/working/output/6317840e9b47/b32fe50b981a/bfded0d02350.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/336f9f6681a0/ (stored 0%)',
#  '  adding: kaggle/working/output/336f9f6681a0/f6a64d5e3164/ (stored 0%)',
#  '  adding: kaggle/working/output/336f9f6681a0/f6a64d5e3164/8c1bc89a7fd8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/b7bc624cf296/ (stored 0%)',
#  '  adding: kaggle/working/output/b7bc624cf296/9ae87dcf7072/ (stored 0%)',
#  '  adding: kaggle/working/output/b7bc624cf296/9ae87dcf7072/eab8dd7373b1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d02dc4dbc13a/ (stored 0%)',
#  '  adding: kaggle/working/output/d02dc4dbc13a/343d6445731e/ (stored 0%)',
#  '  adding: kaggle/working/output/d02dc4dbc13a/343d6445731e/d38cb782f0b3.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d02dc4dbc13a/dd6c5fbafdb6/ (stored 0%)',
#  '  adding: kaggle/working/output/d02dc4dbc13a/dd6c5fbafdb6/2ebe16a053fe.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/babc74e64174/ (stored 0%)',
#  '  adding: kaggle/working/output/babc74e64174/cb2f5b7a7ad1/ (stored 0%)',
#  '  adding: kaggle/working/output/babc74e64174/cb2f5b7a7ad1/ba02b34ea7b3.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/f3eb906bdb01/ (stored 0%)',
#  '  adding: kaggle/working/output/f3eb906bdb01/de1328e0b80c/ (stored 0%)',
#  '  adding: kaggle/working/output/f3eb906bdb01/de1328e0b80c/df77d7ba34cf.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/a27ab5ca843e/ (stored 0%)',
#  '  adding: kaggle/working/output/a27ab5ca843e/74191498ef37/ (stored 0%)',
#  '  adding: kaggle/working/output/a27ab5ca843e/74191498ef37/fb8e258af5e3.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/bbecf7f6c880/ (stored 0%)',
#  '  adding: kaggle/working/output/bbecf7f6c880/9954bc13754c/ (stored 0%)',
#  '  adding: kaggle/working/output/bbecf7f6c880/9954bc13754c/9f3470af5675.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/3f457bc13b99/ (stored 0%)',
#  '  adding: kaggle/working/output/3f457bc13b99/96e725ac5d90/ (stored 0%)',
#  '  adding: kaggle/working/output/3f457bc13b99/96e725ac5d90/5b4bd8fe8138.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/4684064a1c67/ (stored 0%)',
#  '  adding: kaggle/working/output/4684064a1c67/dfe0dac91b66/ (stored 0%)',
#  '  adding: kaggle/working/output/4684064a1c67/dfe0dac91b66/4cc42e634f49.jpg (deflated 6%)',
#  '  adding: kaggle/working/output/6acbdc6c8bf2/ (stored 0%)',
#  '  adding: kaggle/working/output/6acbdc6c8bf2/68114e818554/ (stored 0%)',
#  '  adding: kaggle/working/output/6acbdc6c8bf2/68114e818554/7f9ebbdae8b4.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/a91f96dac3cd/ (stored 0%)',
#  '  adding: kaggle/working/output/a91f96dac3cd/273659632df2/ (stored 0%)',
#  '  adding: kaggle/working/output/a91f96dac3cd/273659632df2/ec106607aaae.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/5c97fb42f06e/ (stored 0%)',
#  '  adding: kaggle/working/output/5c97fb42f06e/da5a513c0a94/ (stored 0%)',
#  '  adding: kaggle/working/output/5c97fb42f06e/da5a513c0a94/2e637e229e50.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/8ac54cf70296/ (stored 0%)',
#  '  adding: kaggle/working/output/8ac54cf70296/36efa4792b64/ (stored 0%)',
#  '  adding: kaggle/working/output/8ac54cf70296/36efa4792b64/c6518cc021fa.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/cfc8a4c873ea/ (stored 0%)',
#  '  adding: kaggle/working/output/cfc8a4c873ea/1dc0272c75e4/ (stored 0%)',
#  '  adding: kaggle/working/output/cfc8a4c873ea/1dc0272c75e4/eb255becb30a.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/db1bb68655fc/ (stored 0%)',
#  '  adding: kaggle/working/output/db1bb68655fc/b40c70f7b1af/ (stored 0%)',
#  '  adding: kaggle/working/output/db1bb68655fc/b40c70f7b1af/f20015a346df.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/2222b92077a6/ (stored 0%)',
#  '  adding: kaggle/working/output/2222b92077a6/4000116cb108/ (stored 0%)',
#  '  adding: kaggle/working/output/2222b92077a6/4000116cb108/1d96a1349a36.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/8b142bc65db2/ (stored 0%)',
#  '  adding: kaggle/working/output/8b142bc65db2/bc0529ff3c2a/ (stored 0%)',
#  '  adding: kaggle/working/output/8b142bc65db2/bc0529ff3c2a/b0fdac52f1d4.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/172e2caf0eb4/ (stored 0%)',
#  '  adding: kaggle/working/output/172e2caf0eb4/8945cb788306/ (stored 0%)',
#  '  adding: kaggle/working/output/172e2caf0eb4/8945cb788306/93979c3e3177.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/172e2caf0eb4/af28f8e6a9e5/ (stored 0%)',
#  '  adding: kaggle/working/output/172e2caf0eb4/af28f8e6a9e5/72cf260ddf4c.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/a2172305e7ba/ (stored 0%)',
#  '  adding: kaggle/working/output/a2172305e7ba/96c826525121/ (stored 0%)',
#  '  adding: kaggle/working/output/a2172305e7ba/96c826525121/95e2769d4d84.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/db70f01df58b/ (stored 0%)',
#  '  adding: kaggle/working/output/db70f01df58b/7e9ee2f37c4d/ (stored 0%)',
#  '  adding: kaggle/working/output/db70f01df58b/7e9ee2f37c4d/62942080d0b6.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/ba72d9d6b562/ (stored 0%)',
#  '  adding: kaggle/working/output/ba72d9d6b562/52fc5d730a77/ (stored 0%)',
#  '  adding: kaggle/working/output/ba72d9d6b562/52fc5d730a77/7ad1c416e505.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/c0527255e849/ (stored 0%)',
#  '  adding: kaggle/working/output/c0527255e849/afed3f813e2b/ (stored 0%)',
#  '  adding: kaggle/working/output/c0527255e849/afed3f813e2b/b37f6a547874.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/0c6c01fafe3e/ (stored 0%)',
#  '  adding: kaggle/working/output/0c6c01fafe3e/333c5337bcd3/ (stored 0%)',
#  '  adding: kaggle/working/output/0c6c01fafe3e/333c5337bcd3/28c11c43c67e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/31c8e40bf4bb/ (stored 0%)',
#  '  adding: kaggle/working/output/31c8e40bf4bb/1f857c6d74b0/ (stored 0%)',
#  '  adding: kaggle/working/output/31c8e40bf4bb/1f857c6d74b0/5146b7667126.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/706310d67811/ (stored 0%)',
#  '  adding: kaggle/working/output/706310d67811/8111d625ca30/ (stored 0%)',
#  '  adding: kaggle/working/output/706310d67811/8111d625ca30/a3e473d88466.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/9b74cea0d6b1/ (stored 0%)',
#  '  adding: kaggle/working/output/9b74cea0d6b1/afb1b04bf142/ (stored 0%)',
#  '  adding: kaggle/working/output/9b74cea0d6b1/afb1b04bf142/5ef8fda13991.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/79ec91f1194c/ (stored 0%)',
#  '  adding: kaggle/working/output/79ec91f1194c/9f30a2fb8635/ (stored 0%)',
#  '  adding: kaggle/working/output/79ec91f1194c/9f30a2fb8635/8e905f69e77c.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/059fb5105884/ (stored 0%)',
#  '  adding: kaggle/working/output/059fb5105884/b1717c704899/ (stored 0%)',
#  '  adding: kaggle/working/output/059fb5105884/b1717c704899/78a1960aa312.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/60e1338439e7/ (stored 0%)',
#  '  adding: kaggle/working/output/60e1338439e7/e8f05878eec2/ (stored 0%)',
#  '  adding: kaggle/working/output/60e1338439e7/e8f05878eec2/44fd41135c61.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/4926a4aa705d/ (stored 0%)',
#  '  adding: kaggle/working/output/4926a4aa705d/3d6e1ac71b1b/ (stored 0%)',
#  '  adding: kaggle/working/output/4926a4aa705d/3d6e1ac71b1b/0c39bc33ac7a.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/417584cecd96/ (stored 0%)',
#  '  adding: kaggle/working/output/417584cecd96/094280f342da/ (stored 0%)',
#  '  adding: kaggle/working/output/417584cecd96/094280f342da/ecdb5a0dcd17.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/483df72733f3/ (stored 0%)',
#  '  adding: kaggle/working/output/483df72733f3/96ed52859cda/ (stored 0%)',
#  '  adding: kaggle/working/output/483df72733f3/96ed52859cda/41bbcaaf83a2.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/bf3ba5075cab/ (stored 0%)',
#  '  adding: kaggle/working/output/bf3ba5075cab/75996ca60e2f/ (stored 0%)',
#  '  adding: kaggle/working/output/bf3ba5075cab/75996ca60e2f/696dd2b20ebc.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/57ca1820340c/ (stored 0%)',
#  '  adding: kaggle/working/output/57ca1820340c/f8e86afee629/ (stored 0%)',
#  '  adding: kaggle/working/output/57ca1820340c/f8e86afee629/4d21277abe60.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/334ac465b405/ (stored 0%)',
#  '  adding: kaggle/working/output/334ac465b405/80505660e9b7/ (stored 0%)',
#  '  adding: kaggle/working/output/334ac465b405/80505660e9b7/25dc34341bbd.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/324b025d8c13/ (stored 0%)',
#  '  adding: kaggle/working/output/324b025d8c13/afa0c10ffc21/ (stored 0%)',
#  '  adding: kaggle/working/output/324b025d8c13/afa0c10ffc21/1563b7136682.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/c8939c198758/ (stored 0%)',
#  '  adding: kaggle/working/output/c8939c198758/979dc2327a73/ (stored 0%)',
#  '  adding: kaggle/working/output/c8939c198758/979dc2327a73/5abee60d1a9b.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/8dd03d75fbbc/ (stored 0%)',
#  '  adding: kaggle/working/output/8dd03d75fbbc/020fe873a405/ (stored 0%)',
#  '  adding: kaggle/working/output/8dd03d75fbbc/020fe873a405/fee6b3f57081.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/642ffa5c3a59/ (stored 0%)',
#  '  adding: kaggle/working/output/642ffa5c3a59/ffc4197a2c95/ (stored 0%)',
#  '  adding: kaggle/working/output/642ffa5c3a59/ffc4197a2c95/f1a3cf9d3471.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/f7d8873478ac/ (stored 0%)',
#  '  adding: kaggle/working/output/f7d8873478ac/09acc6e9b79d/ (stored 0%)',
#  '  adding: kaggle/working/output/f7d8873478ac/09acc6e9b79d/3b8707263b78.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/37befe3703ab/ (stored 0%)',
#  '  adding: kaggle/working/output/37befe3703ab/13fb7f28098a/ (stored 0%)',
#  '  adding: kaggle/working/output/37befe3703ab/13fb7f28098a/f6ef78fff495.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/b972189fc63f/ (stored 0%)',
#  '  adding: kaggle/working/output/b972189fc63f/207fc80ee3e2/ (stored 0%)',
#  '  adding: kaggle/working/output/b972189fc63f/207fc80ee3e2/22cd8d57d2b1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/9d398b995734/ (stored 0%)',
#  '  adding: kaggle/working/output/9d398b995734/0cf5634fed79/ (stored 0%)',
#  '  adding: kaggle/working/output/9d398b995734/0cf5634fed79/b7c97ac36b5e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/b8727a84ded6/ (stored 0%)',
#  '  adding: kaggle/working/output/b8727a84ded6/527acea1973e/ (stored 0%)',
#  '  adding: kaggle/working/output/b8727a84ded6/527acea1973e/b409851e44e6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/30c9e5013527/ (stored 0%)',
#  '  adding: kaggle/working/output/30c9e5013527/1f9b28aeacab/ (stored 0%)',
#  '  adding: kaggle/working/output/30c9e5013527/1f9b28aeacab/4584a4dd0ec8.jpg (deflated 5%)',
#  '  adding: kaggle/working/output/c6af19161721/ (stored 0%)',
#  '  adding: kaggle/working/output/c6af19161721/1c969fc17960/ (stored 0%)',
#  '  adding: kaggle/working/output/c6af19161721/1c969fc17960/8ab8682e8bc6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/c6af19161721/d3ec7f8c6e74/ (stored 0%)',
#  '  adding: kaggle/working/output/c6af19161721/d3ec7f8c6e74/a2ee4b862182.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/50586fea5441/ (stored 0%)',
#  '  adding: kaggle/working/output/50586fea5441/9c8ef88ba0fe/ (stored 0%)',
#  '  adding: kaggle/working/output/50586fea5441/9c8ef88ba0fe/7ac0b1312f61.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/db5be2895a72/ (stored 0%)',
#  '  adding: kaggle/working/output/db5be2895a72/4309ad227a5a/ (stored 0%)',
#  '  adding: kaggle/working/output/db5be2895a72/4309ad227a5a/5cb08cd3bea3.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/60b307a1d9c7/ (stored 0%)',
#  '  adding: kaggle/working/output/60b307a1d9c7/8dba7bb8b7d5/ (stored 0%)',
#  '  adding: kaggle/working/output/60b307a1d9c7/8dba7bb8b7d5/e67d15264570.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/2edb1488b0b2/ (stored 0%)',
#  '  adding: kaggle/working/output/2edb1488b0b2/508b3fef3575/ (stored 0%)',
#  '  adding: kaggle/working/output/2edb1488b0b2/508b3fef3575/dbc311ed04b5.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/2edb1488b0b2/4a1f77a49d6e/ (stored 0%)',
#  '  adding: kaggle/working/output/2edb1488b0b2/4a1f77a49d6e/2fa1e735585b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/1a58b43cf286/ (stored 0%)',
#  '  adding: kaggle/working/output/1a58b43cf286/0704ff4c28b5/ (stored 0%)',
#  '  adding: kaggle/working/output/1a58b43cf286/0704ff4c28b5/cada5310214b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/1a58b43cf286/461096d084ba/ (stored 0%)',
#  '  adding: kaggle/working/output/1a58b43cf286/461096d084ba/00c1515729a8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/bbebf4a7d2df/ (stored 0%)',
#  '  adding: kaggle/working/output/bbebf4a7d2df/d60da771f99b/ (stored 0%)',
#  '  adding: kaggle/working/output/bbebf4a7d2df/d60da771f99b/ae21e4271637.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/d8f6fee0e95e/ (stored 0%)',
#  '  adding: kaggle/working/output/d8f6fee0e95e/30b848c98944/ (stored 0%)',
#  '  adding: kaggle/working/output/d8f6fee0e95e/30b848c98944/7bc910d02031.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/fda24ef37907/ (stored 0%)',
#  '  adding: kaggle/working/output/fda24ef37907/71d5c89edda0/ (stored 0%)',
#  '  adding: kaggle/working/output/fda24ef37907/71d5c89edda0/cb8664074d11.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/771a4add61c9/ (stored 0%)',
#  '  adding: kaggle/working/output/771a4add61c9/5b2c33e326e9/ (stored 0%)',
#  '  adding: kaggle/working/output/771a4add61c9/5b2c33e326e9/a61ef3082c98.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/3e598b90e0db/ (stored 0%)',
#  '  adding: kaggle/working/output/3e598b90e0db/5b988b860efb/ (stored 0%)',
#  '  adding: kaggle/working/output/3e598b90e0db/5b988b860efb/bb9ab7ff9a3e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/8c382f780705/ (stored 0%)',
#  '  adding: kaggle/working/output/8c382f780705/c88eaa06413c/ (stored 0%)',
#  '  adding: kaggle/working/output/8c382f780705/c88eaa06413c/5577578a9f6a.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d0e855bbced0/ (stored 0%)',
#  '  adding: kaggle/working/output/d0e855bbced0/827b203a514d/ (stored 0%)',
#  '  adding: kaggle/working/output/d0e855bbced0/827b203a514d/58aab279543f.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/2f9246cbb78a/ (stored 0%)',
#  '  adding: kaggle/working/output/2f9246cbb78a/70bccfc8c906/ (stored 0%)',
#  '  adding: kaggle/working/output/2f9246cbb78a/70bccfc8c906/67b1b1cc7551.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/11961f06a9b0/ (stored 0%)',
#  '  adding: kaggle/working/output/11961f06a9b0/0a53e88aeded/ (stored 0%)',
#  '  adding: kaggle/working/output/11961f06a9b0/0a53e88aeded/28d1dc56e056.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/68370c4bcdc6/ (stored 0%)',
#  '  adding: kaggle/working/output/68370c4bcdc6/cc4408fc45bd/ (stored 0%)',
#  '  adding: kaggle/working/output/68370c4bcdc6/cc4408fc45bd/d0251cb64bb6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/180602a700b7/ (stored 0%)',
#  '  adding: kaggle/working/output/180602a700b7/16862c4d6b67/ (stored 0%)',
#  '  adding: kaggle/working/output/180602a700b7/16862c4d6b67/5bbffdf01f8a.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/5cb7b038e5fb/ (stored 0%)',
#  '  adding: kaggle/working/output/5cb7b038e5fb/8f858ccf6515/ (stored 0%)',
#  '  adding: kaggle/working/output/5cb7b038e5fb/8f858ccf6515/4c795028272e.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/460e1bb0eb6c/ (stored 0%)',
#  '  adding: kaggle/working/output/460e1bb0eb6c/75183aefbc7b/ (stored 0%)',
#  '  adding: kaggle/working/output/460e1bb0eb6c/75183aefbc7b/289057c7f38c.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d3cf46c2aa95/ (stored 0%)',
#  '  adding: kaggle/working/output/d3cf46c2aa95/d557a75bc8d3/ (stored 0%)',
#  '  adding: kaggle/working/output/d3cf46c2aa95/d557a75bc8d3/40684c5ec4d8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/88de39a40a62/ (stored 0%)',
#  '  adding: kaggle/working/output/88de39a40a62/744df4c6edc5/ (stored 0%)',
#  '  adding: kaggle/working/output/88de39a40a62/744df4c6edc5/78f5d0c4f4d6.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/bda0602c708b/ (stored 0%)',
#  '  adding: kaggle/working/output/bda0602c708b/13cb73bf378e/ (stored 0%)',
#  '  adding: kaggle/working/output/bda0602c708b/13cb73bf378e/71e0d3c3bc14.jpg (deflated 4%)',
#  '  adding: kaggle/working/output/e094984999c2/ (stored 0%)',
#  '  adding: kaggle/working/output/e094984999c2/239d24cec3ab/ (stored 0%)',
#  '  adding: kaggle/working/output/e094984999c2/239d24cec3ab/76d45ddd80d8.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/29cd2e8cd19c/ (stored 0%)',
#  '  adding: kaggle/working/output/29cd2e8cd19c/39f759299c34/ (stored 0%)',
#  '  adding: kaggle/working/output/29cd2e8cd19c/39f759299c34/31b0dc31da93.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/6b9b82594fcd/ (stored 0%)',
#  '  adding: kaggle/working/output/6b9b82594fcd/c94f6b341895/ (stored 0%)',
#  '  adding: kaggle/working/output/6b9b82594fcd/c94f6b341895/72b3a9d784f7.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/9e99231860d5/ (stored 0%)',
#  '  adding: kaggle/working/output/9e99231860d5/a62c0ac16512/ (stored 0%)',
#  '  adding: kaggle/working/output/9e99231860d5/a62c0ac16512/895ee33c70a1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/8f83ac5ef880/ (stored 0%)',
#  '  adding: kaggle/working/output/8f83ac5ef880/b4680853c2c2/ (stored 0%)',
#  '  adding: kaggle/working/output/8f83ac5ef880/b4680853c2c2/36d85956f758.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/6ea453b90c6c/ (stored 0%)',
#  '  adding: kaggle/working/output/6ea453b90c6c/e14837e994a2/ (stored 0%)',
#  '  adding: kaggle/working/output/6ea453b90c6c/e14837e994a2/6d6f7276dafe.jpg (deflated 4%)',
#  '  adding: kaggle/working/output/1ce3a5d2f184/ (stored 0%)',
#  '  adding: kaggle/working/output/1ce3a5d2f184/2a52989ea7cc/ (stored 0%)',
#  '  adding: kaggle/working/output/1ce3a5d2f184/2a52989ea7cc/4bbe8d48fd9a.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/eb76ebad1c23/ (stored 0%)',
#  '  adding: kaggle/working/output/eb76ebad1c23/a5d2c6608d0c/ (stored 0%)',
#  '  adding: kaggle/working/output/eb76ebad1c23/a5d2c6608d0c/4c3acc13335c.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/7a222273085d/ (stored 0%)',
#  '  adding: kaggle/working/output/7a222273085d/676aa8dc3412/ (stored 0%)',
#  '  adding: kaggle/working/output/7a222273085d/676aa8dc3412/972de759ed96.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/263e1aad5f55/ (stored 0%)',
#  '  adding: kaggle/working/output/263e1aad5f55/fd4a02fffcc0/ (stored 0%)',
#  '  adding: kaggle/working/output/263e1aad5f55/fd4a02fffcc0/d7bfa952bccd.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/f0a6dc99b78a/ (stored 0%)',
#  '  adding: kaggle/working/output/f0a6dc99b78a/5038cebbed84/ (stored 0%)',
#  '  adding: kaggle/working/output/f0a6dc99b78a/5038cebbed84/cdf2deb57f28.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/c94e9f51c8bf/ (stored 0%)',
#  '  adding: kaggle/working/output/c94e9f51c8bf/5cd9e4b0c809/ (stored 0%)',
#  '  adding: kaggle/working/output/c94e9f51c8bf/5cd9e4b0c809/21b11b97837b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/db9f9c62dc00/ (stored 0%)',
#  '  adding: kaggle/working/output/db9f9c62dc00/90e3abda431d/ (stored 0%)',
#  '  adding: kaggle/working/output/db9f9c62dc00/90e3abda431d/6ffef23b4aa9.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/3a0ce16d6362/ (stored 0%)',
#  '  adding: kaggle/working/output/3a0ce16d6362/412e53b5cf60/ (stored 0%)',
#  '  adding: kaggle/working/output/3a0ce16d6362/412e53b5cf60/b63ca8a1327c.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/09fb4da6ca2f/ (stored 0%)',
#  '  adding: kaggle/working/output/09fb4da6ca2f/abee232d10d0/ (stored 0%)',
#  '  adding: kaggle/working/output/09fb4da6ca2f/abee232d10d0/c326bbab94e8.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/fb5044f382e3/ (stored 0%)',
#  '  adding: kaggle/working/output/fb5044f382e3/f049e2e9401a/ (stored 0%)',
#  '  adding: kaggle/working/output/fb5044f382e3/f049e2e9401a/a510b3efc3cc.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/4e6e5c81a79c/ (stored 0%)',
#  '  adding: kaggle/working/output/4e6e5c81a79c/8a5b80aa26f4/ (stored 0%)',
#  '  adding: kaggle/working/output/4e6e5c81a79c/8a5b80aa26f4/2c4e95472ebb.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/486c0b27043a/ (stored 0%)',
#  '  adding: kaggle/working/output/486c0b27043a/370f6172f340/ (stored 0%)',
#  '  adding: kaggle/working/output/486c0b27043a/370f6172f340/9ce5032a4dfd.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/262dd75dd358/ (stored 0%)',
#  '  adding: kaggle/working/output/262dd75dd358/51a983917491/ (stored 0%)',
#  '  adding: kaggle/working/output/262dd75dd358/51a983917491/9b531d53c513.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/3a3975e0fae6/ (stored 0%)',
#  '  adding: kaggle/working/output/3a3975e0fae6/bcfd939b6e03/ (stored 0%)',
#  '  adding: kaggle/working/output/3a3975e0fae6/bcfd939b6e03/49cbc9c84fac.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/ef3e7ae6e700/ (stored 0%)',
#  '  adding: kaggle/working/output/ef3e7ae6e700/e843ce1f9aaa/ (stored 0%)',
#  '  adding: kaggle/working/output/ef3e7ae6e700/e843ce1f9aaa/0ecb5373eee0.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/99cb5766690f/ (stored 0%)',
#  '  adding: kaggle/working/output/99cb5766690f/1d25a91d91f4/ (stored 0%)',
#  '  adding: kaggle/working/output/99cb5766690f/1d25a91d91f4/8061563f9228.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/51502fa7747d/ (stored 0%)',
#  '  adding: kaggle/working/output/51502fa7747d/d64fd3e4998b/ (stored 0%)',
#  '  adding: kaggle/working/output/51502fa7747d/d64fd3e4998b/5801a49e4c2e.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/5e1e833afeeb/ (stored 0%)',
#  '  adding: kaggle/working/output/5e1e833afeeb/e5a00df91392/ (stored 0%)',
#  '  adding: kaggle/working/output/5e1e833afeeb/e5a00df91392/bb0435db5c6d.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/5423b19fb38b/ (stored 0%)',
#  '  adding: kaggle/working/output/5423b19fb38b/010501ba4682/ (stored 0%)',
#  '  adding: kaggle/working/output/5423b19fb38b/010501ba4682/8d707af243eb.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/6a80b8290f19/ (stored 0%)',
#  '  adding: kaggle/working/output/6a80b8290f19/ba98889e91b1/ (stored 0%)',
#  '  adding: kaggle/working/output/6a80b8290f19/ba98889e91b1/2db8cefa1c69.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/0ee703df04a3/ (stored 0%)',
#  '  adding: kaggle/working/output/0ee703df04a3/3936832bd9c5/ (stored 0%)',
#  '  adding: kaggle/working/output/0ee703df04a3/3936832bd9c5/60a3a716ccba.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/18a530e6a802/ (stored 0%)',
#  '  adding: kaggle/working/output/18a530e6a802/f04a2978bc3e/ (stored 0%)',
#  '  adding: kaggle/working/output/18a530e6a802/f04a2978bc3e/32e5cba874ee.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/b119ef635297/ (stored 0%)',
#  '  adding: kaggle/working/output/b119ef635297/6d77cb2ac775/ (stored 0%)',
#  '  adding: kaggle/working/output/b119ef635297/6d77cb2ac775/b7df05b419df.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/f0f8ccd8b0a0/ (stored 0%)',
#  '  adding: kaggle/working/output/f0f8ccd8b0a0/c72f5beef2a4/ (stored 0%)',
#  '  adding: kaggle/working/output/f0f8ccd8b0a0/c72f5beef2a4/9c316285e3a2.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/bb64d0bf6912/ (stored 0%)',
#  '  adding: kaggle/working/output/bb64d0bf6912/5de58ac56418/ (stored 0%)',
#  '  adding: kaggle/working/output/bb64d0bf6912/5de58ac56418/1e1a624d65a6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/c2adb9afbb5f/ (stored 0%)',
#  '  adding: kaggle/working/output/c2adb9afbb5f/12e52d3f7c3b/ (stored 0%)',
#  '  adding: kaggle/working/output/c2adb9afbb5f/12e52d3f7c3b/6ecd31b63948.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/44b3c1b1bf89/ (stored 0%)',
#  '  adding: kaggle/working/output/44b3c1b1bf89/4b6caf8f89dc/ (stored 0%)',
#  '  adding: kaggle/working/output/44b3c1b1bf89/4b6caf8f89dc/38db8a56a857.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/06dc92c4302a/ (stored 0%)',
#  '  adding: kaggle/working/output/06dc92c4302a/e1c13867cbd9/ (stored 0%)',
#  '  adding: kaggle/working/output/06dc92c4302a/e1c13867cbd9/dd24bff49c63.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/02bfa5949092/ (stored 0%)',
#  '  adding: kaggle/working/output/02bfa5949092/5232316db701/ (stored 0%)',
#  '  adding: kaggle/working/output/02bfa5949092/5232316db701/302436633ec0.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/e6822cd9cd0b/ (stored 0%)',
#  '  adding: kaggle/working/output/e6822cd9cd0b/cb6c5f8d4d85/ (stored 0%)',
#  '  adding: kaggle/working/output/e6822cd9cd0b/cb6c5f8d4d85/6c8fb4dd5fd7.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/52dc05bd4381/ (stored 0%)',
#  '  adding: kaggle/working/output/52dc05bd4381/e949c798ecd1/ (stored 0%)',
#  '  adding: kaggle/working/output/52dc05bd4381/e949c798ecd1/fdb87f885d0e.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/24c3867c5d29/ (stored 0%)',
#  '  adding: kaggle/working/output/24c3867c5d29/8ca8e2b0ab62/ (stored 0%)',
#  '  adding: kaggle/working/output/24c3867c5d29/8ca8e2b0ab62/97debe0b73fa.jpg (stored 0%)',
#  '  adding: kaggle/working/output/d7561eaf0b7d/ (stored 0%)',
#  '  adding: kaggle/working/output/d7561eaf0b7d/62d7d0a10c73/ (stored 0%)',
#  '  adding: kaggle/working/output/d7561eaf0b7d/62d7d0a10c73/e366fa659c3a.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/145a2c752783/ (stored 0%)',
#  '  adding: kaggle/working/output/145a2c752783/16cf53eefc68/ (stored 0%)',
#  '  adding: kaggle/working/output/145a2c752783/16cf53eefc68/faca5b0d2002.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/8cf2f88c1831/ (stored 0%)',
#  '  adding: kaggle/working/output/8cf2f88c1831/cb3559ac3918/ (stored 0%)',
#  '  adding: kaggle/working/output/8cf2f88c1831/cb3559ac3918/d55d4bf95360.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/af4e1dfa2f63/ (stored 0%)',
#  '  adding: kaggle/working/output/af4e1dfa2f63/a08655135000/ (stored 0%)',
#  '  adding: kaggle/working/output/af4e1dfa2f63/a08655135000/f258c4e97218.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/7064f1df2a5a/ (stored 0%)',
#  '  adding: kaggle/working/output/7064f1df2a5a/b0d0b514389c/ (stored 0%)',
#  '  adding: kaggle/working/output/7064f1df2a5a/b0d0b514389c/41e9a794b342.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/7064f1df2a5a/e65e1cc92269/ (stored 0%)',
#  '  adding: kaggle/working/output/7064f1df2a5a/e65e1cc92269/2f973757eaa4.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/13e21ab810f1/ (stored 0%)',
#  '  adding: kaggle/working/output/13e21ab810f1/a441adfc71e4/ (stored 0%)',
#  '  adding: kaggle/working/output/13e21ab810f1/a441adfc71e4/2d608b540059.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/0725e859c8de/ (stored 0%)',
#  '  adding: kaggle/working/output/0725e859c8de/6c6eabcd9632/ (stored 0%)',
#  '  adding: kaggle/working/output/0725e859c8de/6c6eabcd9632/52420ef26cc3.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/12ea5fffe282/ (stored 0%)',
#  '  adding: kaggle/working/output/12ea5fffe282/120c1b6fdfc6/ (stored 0%)',
#  '  adding: kaggle/working/output/12ea5fffe282/120c1b6fdfc6/9b5846c01320.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/f17665afc4c2/ (stored 0%)',
#  '  adding: kaggle/working/output/f17665afc4c2/4181c6edfe25/ (stored 0%)',
#  '  adding: kaggle/working/output/f17665afc4c2/4181c6edfe25/502e912e6eb4.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/4c1e5ca11b6e/ (stored 0%)',
#  '  adding: kaggle/working/output/4c1e5ca11b6e/3e493dd828b3/ (stored 0%)',
#  '  adding: kaggle/working/output/4c1e5ca11b6e/3e493dd828b3/103bd9ed3929.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/4c1e5ca11b6e/a45a005bf16c/ (stored 0%)',
#  '  adding: kaggle/working/output/4c1e5ca11b6e/a45a005bf16c/8e1f49b85369.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/5f9127732aa5/ (stored 0%)',
#  '  adding: kaggle/working/output/5f9127732aa5/27c1c74bd381/ (stored 0%)',
#  '  adding: kaggle/working/output/5f9127732aa5/27c1c74bd381/702b9333c3a8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/68711c5bfca0/ (stored 0%)',
#  '  adding: kaggle/working/output/68711c5bfca0/3cbd736d19bb/ (stored 0%)',
#  '  adding: kaggle/working/output/68711c5bfca0/3cbd736d19bb/09edc6b22778.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/d21c4a44ca5d/ (stored 0%)',
#  '  adding: kaggle/working/output/d21c4a44ca5d/75804bfddb06/ (stored 0%)',
#  '  adding: kaggle/working/output/d21c4a44ca5d/75804bfddb06/851cf518efcc.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d72d10b54d44/ (stored 0%)',
#  '  adding: kaggle/working/output/d72d10b54d44/114d58009cf8/ (stored 0%)',
#  '  adding: kaggle/working/output/d72d10b54d44/114d58009cf8/e885aaec6e66.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/159cbf48e73c/ (stored 0%)',
#  '  adding: kaggle/working/output/159cbf48e73c/48d2c4199329/ (stored 0%)',
#  '  adding: kaggle/working/output/159cbf48e73c/48d2c4199329/ac8e240acf88.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/39a80a14bfda/ (stored 0%)',
#  '  adding: kaggle/working/output/39a80a14bfda/088a20979e31/ (stored 0%)',
#  '  adding: kaggle/working/output/39a80a14bfda/088a20979e31/008ca392cff3.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/2b69ea062f72/ (stored 0%)',
#  '  adding: kaggle/working/output/2b69ea062f72/4f5c4e845d74/ (stored 0%)',
#  '  adding: kaggle/working/output/2b69ea062f72/4f5c4e845d74/56cdb0916363.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/511b76817a88/ (stored 0%)',
#  '  adding: kaggle/working/output/511b76817a88/4b0e5a1efd64/ (stored 0%)',
#  '  adding: kaggle/working/output/511b76817a88/4b0e5a1efd64/cade101ed1d8.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/a5b9482cfa77/ (stored 0%)',
#  '  adding: kaggle/working/output/a5b9482cfa77/89c40dca0c1a/ (stored 0%)',
#  '  adding: kaggle/working/output/a5b9482cfa77/89c40dca0c1a/f3728a2aa0e9.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/08872a6c1b69/ (stored 0%)',
#  '  adding: kaggle/working/output/08872a6c1b69/094b50a7de19/ (stored 0%)',
#  '  adding: kaggle/working/output/08872a6c1b69/094b50a7de19/9a1809c1437e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/2b2548a40da2/ (stored 0%)',
#  '  adding: kaggle/working/output/2b2548a40da2/1bb1625d8947/ (stored 0%)',
#  '  adding: kaggle/working/output/2b2548a40da2/1bb1625d8947/c41faeef254c.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/edb5e43491c4/ (stored 0%)',
#  '  adding: kaggle/working/output/edb5e43491c4/170fd32e8cdb/ (stored 0%)',
#  '  adding: kaggle/working/output/edb5e43491c4/170fd32e8cdb/c86ec745fa23.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/c4ded198c3f1/ (stored 0%)',
#  '  adding: kaggle/working/output/c4ded198c3f1/b34a80f81d92/ (stored 0%)',
#  '  adding: kaggle/working/output/c4ded198c3f1/b34a80f81d92/eef9600e5493.jpg (deflated 4%)',
#  '  adding: kaggle/working/output/f15cf4fdbbfb/ (stored 0%)',
#  '  adding: kaggle/working/output/f15cf4fdbbfb/4c2aa7b4e90e/ (stored 0%)',
#  '  adding: kaggle/working/output/f15cf4fdbbfb/4c2aa7b4e90e/dba223ee6a22.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/fab641b3ce7c/ (stored 0%)',
#  '  adding: kaggle/working/output/fab641b3ce7c/82fb75bee506/ (stored 0%)',
#  '  adding: kaggle/working/output/fab641b3ce7c/82fb75bee506/c2d72bbff9fc.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/3e0dde11b059/ (stored 0%)',
#  '  adding: kaggle/working/output/3e0dde11b059/2a751e61b11e/ (stored 0%)',
#  '  adding: kaggle/working/output/3e0dde11b059/2a751e61b11e/ac1c89907fa2.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/c6c5e04f3a24/ (stored 0%)',
#  '  adding: kaggle/working/output/c6c5e04f3a24/819e5d560493/ (stored 0%)',
#  '  adding: kaggle/working/output/c6c5e04f3a24/819e5d560493/6a8ed4525b97.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/1c939db63c15/ (stored 0%)',
#  '  adding: kaggle/working/output/1c939db63c15/d412342fe6fa/ (stored 0%)',
#  '  adding: kaggle/working/output/1c939db63c15/d412342fe6fa/282846988f20.jpg (deflated 6%)',
#  '  adding: kaggle/working/output/96533d9801a9/ (stored 0%)',
#  '  adding: kaggle/working/output/96533d9801a9/8cb22030693f/ (stored 0%)',
#  '  adding: kaggle/working/output/96533d9801a9/8cb22030693f/6483231bcfbb.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/c229eccad476/ (stored 0%)',
#  '  adding: kaggle/working/output/c229eccad476/22b57bedc9e0/ (stored 0%)',
#  '  adding: kaggle/working/output/c229eccad476/22b57bedc9e0/ade3c3a06a61.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/f8c006d79bd7/ (stored 0%)',
#  '  adding: kaggle/working/output/f8c006d79bd7/f4b5fac29fda/ (stored 0%)',
#  '  adding: kaggle/working/output/f8c006d79bd7/f4b5fac29fda/263c477e8df6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/3ed3d85a4caa/ (stored 0%)',
#  '  adding: kaggle/working/output/3ed3d85a4caa/23d55edbf6a8/ (stored 0%)',
#  '  adding: kaggle/working/output/3ed3d85a4caa/23d55edbf6a8/732668dc8b67.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/9ff049a6b395/ (stored 0%)',
#  '  adding: kaggle/working/output/9ff049a6b395/91114ee1a222/ (stored 0%)',
#  '  adding: kaggle/working/output/9ff049a6b395/91114ee1a222/9435525bf9f8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/e27dbf267565/ (stored 0%)',
#  '  adding: kaggle/working/output/e27dbf267565/9ed48f5eb5db/ (stored 0%)',
#  '  adding: kaggle/working/output/e27dbf267565/9ed48f5eb5db/ba582d441629.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/f80048310b29/ (stored 0%)',
#  '  adding: kaggle/working/output/f80048310b29/dfb1ac1ad582/ (stored 0%)',
#  '  adding: kaggle/working/output/f80048310b29/dfb1ac1ad582/5b1a846b9f01.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/b5e30871622c/ (stored 0%)',
#  '  adding: kaggle/working/output/b5e30871622c/3f99980ae49c/ (stored 0%)',
#  '  adding: kaggle/working/output/b5e30871622c/3f99980ae49c/f2044befe4f9.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/23818431bd20/ (stored 0%)',
#  '  adding: kaggle/working/output/23818431bd20/5efb19d20ad5/ (stored 0%)',
#  '  adding: kaggle/working/output/23818431bd20/5efb19d20ad5/2d409ccd6f6d.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/7a4341a6a2ee/ (stored 0%)',
#  '  adding: kaggle/working/output/7a4341a6a2ee/d7d25e244f59/ (stored 0%)',
#  '  adding: kaggle/working/output/7a4341a6a2ee/d7d25e244f59/6df0ff8cce41.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/570e81ad62f3/ (stored 0%)',
#  '  adding: kaggle/working/output/570e81ad62f3/4676e96ae640/ (stored 0%)',
#  '  adding: kaggle/working/output/570e81ad62f3/4676e96ae640/ca6a63a554c7.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/eb41a8fdece4/ (stored 0%)',
#  '  adding: kaggle/working/output/eb41a8fdece4/8a78d97ecbfe/ (stored 0%)',
#  '  adding: kaggle/working/output/eb41a8fdece4/8a78d97ecbfe/35a789322c1d.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/d745f58d5aff/ (stored 0%)',
#  '  adding: kaggle/working/output/d745f58d5aff/f33f28775f83/ (stored 0%)',
#  '  adding: kaggle/working/output/d745f58d5aff/f33f28775f83/933f80e2c741.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/4b93ca3c31ad/ (stored 0%)',
#  '  adding: kaggle/working/output/4b93ca3c31ad/880417c8542a/ (stored 0%)',
#  '  adding: kaggle/working/output/4b93ca3c31ad/880417c8542a/b570de3efeed.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/5c20d46146b3/ (stored 0%)',
#  '  adding: kaggle/working/output/5c20d46146b3/4203f76abd9d/ (stored 0%)',
#  '  adding: kaggle/working/output/5c20d46146b3/4203f76abd9d/3ad901a1a44e.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/a7c66f4267fd/ (stored 0%)',
#  '  adding: kaggle/working/output/a7c66f4267fd/93e4372cdf61/ (stored 0%)',
#  '  adding: kaggle/working/output/a7c66f4267fd/93e4372cdf61/f7b650573906.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/22686edb0131/ (stored 0%)',
#  '  adding: kaggle/working/output/22686edb0131/cf6a4bc17b35/ (stored 0%)',
#  '  adding: kaggle/working/output/22686edb0131/cf6a4bc17b35/760bc20f4476.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/a5656b78cc0e/ (stored 0%)',
#  '  adding: kaggle/working/output/a5656b78cc0e/389351586b51/ (stored 0%)',
#  '  adding: kaggle/working/output/a5656b78cc0e/389351586b51/ba9686fa29f2.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/f98438a1cf12/ (stored 0%)',
#  '  adding: kaggle/working/output/f98438a1cf12/6708de462f1e/ (stored 0%)',
#  '  adding: kaggle/working/output/f98438a1cf12/6708de462f1e/6713c2b6c0a6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/7c3b534b7eca/ (stored 0%)',
#  '  adding: kaggle/working/output/7c3b534b7eca/64e6b080865a/ (stored 0%)',
#  '  adding: kaggle/working/output/7c3b534b7eca/64e6b080865a/3b7033af4649.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/dfc0decef09f/ (stored 0%)',
#  '  adding: kaggle/working/output/dfc0decef09f/b640d37dfbfe/ (stored 0%)',
#  '  adding: kaggle/working/output/dfc0decef09f/b640d37dfbfe/c9132d004fb0.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/7ea9b8b90bda/ (stored 0%)',
#  '  adding: kaggle/working/output/7ea9b8b90bda/503c9544eadc/ (stored 0%)',
#  '  adding: kaggle/working/output/7ea9b8b90bda/503c9544eadc/63aefefa9ee0.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/b171d813782b/ (stored 0%)',
#  '  adding: kaggle/working/output/b171d813782b/a7d9ab0fa3d7/ (stored 0%)',
#  '  adding: kaggle/working/output/b171d813782b/a7d9ab0fa3d7/532f722fa51d.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/07d5f3e47055/ (stored 0%)',
#  '  adding: kaggle/working/output/07d5f3e47055/3e9bf900d8b7/ (stored 0%)',
#  '  adding: kaggle/working/output/07d5f3e47055/3e9bf900d8b7/cf613b0f630e.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/95fb8be641af/ (stored 0%)',
#  '  adding: kaggle/working/output/95fb8be641af/c7cfb655d0f0/ (stored 0%)',
#  '  adding: kaggle/working/output/95fb8be641af/c7cfb655d0f0/592f4c2d20f7.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/162b49bd6d26/ (stored 0%)',
#  '  adding: kaggle/working/output/162b49bd6d26/f0c92c5c83b1/ (stored 0%)',
#  '  adding: kaggle/working/output/162b49bd6d26/f0c92c5c83b1/4f39b14d1bc2.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/0abb818755e4/ (stored 0%)',
#  '  adding: kaggle/working/output/0abb818755e4/044bcf0e94b5/ (stored 0%)',
#  '  adding: kaggle/working/output/0abb818755e4/044bcf0e94b5/42e7ecc6fdb0.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/6ee4d806e567/ (stored 0%)',
#  '  adding: kaggle/working/output/6ee4d806e567/bfb108b4bae0/ (stored 0%)',
#  '  adding: kaggle/working/output/6ee4d806e567/bfb108b4bae0/312566b9d20b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/cfba05e7880c/ (stored 0%)',
#  '  adding: kaggle/working/output/cfba05e7880c/b18e574c45c6/ (stored 0%)',
#  '  adding: kaggle/working/output/cfba05e7880c/b18e574c45c6/3b95973fa9d7.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/9185f141a3c9/ (stored 0%)',
#  '  adding: kaggle/working/output/9185f141a3c9/8480175244c7/ (stored 0%)',
#  '  adding: kaggle/working/output/9185f141a3c9/8480175244c7/5026e8d1e6f9.jpg (deflated 4%)',
#  '  adding: kaggle/working/output/5f23e39538df/ (stored 0%)',
#  '  adding: kaggle/working/output/5f23e39538df/f2bab4c75fd8/ (stored 0%)',
#  '  adding: kaggle/working/output/5f23e39538df/f2bab4c75fd8/dd4b855fb596.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/2f06b076d692/ (stored 0%)',
#  '  adding: kaggle/working/output/2f06b076d692/9eb02f34d623/ (stored 0%)',
#  '  adding: kaggle/working/output/2f06b076d692/9eb02f34d623/0834d60255e3.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/5756aa070207/ (stored 0%)',
#  '  adding: kaggle/working/output/5756aa070207/f1c2a99f9b9b/ (stored 0%)',
#  '  adding: kaggle/working/output/5756aa070207/f1c2a99f9b9b/d176b5544d10.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/f45612bd7e0b/ (stored 0%)',
#  '  adding: kaggle/working/output/f45612bd7e0b/b075778bce13/ (stored 0%)',
#  '  adding: kaggle/working/output/f45612bd7e0b/b075778bce13/8c7bdccb65ed.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/f45612bd7e0b/d5b3d906fd47/ (stored 0%)',
#  '  adding: kaggle/working/output/f45612bd7e0b/d5b3d906fd47/43883549bf9b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/a862fd88bd49/ (stored 0%)',
#  '  adding: kaggle/working/output/a862fd88bd49/59a2f334c7fe/ (stored 0%)',
#  '  adding: kaggle/working/output/a862fd88bd49/59a2f334c7fe/cedb3b72e9f1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/0a49309fc682/ (stored 0%)',
#  '  adding: kaggle/working/output/0a49309fc682/a9d152dbf2ef/ (stored 0%)',
#  '  adding: kaggle/working/output/0a49309fc682/a9d152dbf2ef/0f4bc6a7b8b5.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/9618c3ca410e/ (stored 0%)',
#  '  adding: kaggle/working/output/9618c3ca410e/2a5ba77a9415/ (stored 0%)',
#  '  adding: kaggle/working/output/9618c3ca410e/2a5ba77a9415/10181eeb21eb.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/e9268097a0d1/ (stored 0%)',
#  '  adding: kaggle/working/output/e9268097a0d1/92ad7182a32b/ (stored 0%)',
#  '  adding: kaggle/working/output/e9268097a0d1/92ad7182a32b/bac9d4aa1718.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/3aa2fb153a2f/ (stored 0%)',
#  '  adding: kaggle/working/output/3aa2fb153a2f/16bdde309d1c/ (stored 0%)',
#  '  adding: kaggle/working/output/3aa2fb153a2f/16bdde309d1c/636140b67fd6.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/da0412fab70b/ (stored 0%)',
#  '  adding: kaggle/working/output/da0412fab70b/560c374713b7/ (stored 0%)',
#  '  adding: kaggle/working/output/da0412fab70b/560c374713b7/721efb1d26f9.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/3d7a5814c41f/ (stored 0%)',
#  '  adding: kaggle/working/output/3d7a5814c41f/46137a3017bf/ (stored 0%)',
#  '  adding: kaggle/working/output/3d7a5814c41f/46137a3017bf/60b076f811eb.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/b88a5fb42602/ (stored 0%)',
#  '  adding: kaggle/working/output/b88a5fb42602/b66f91daada1/ (stored 0%)',
#  '  adding: kaggle/working/output/b88a5fb42602/b66f91daada1/8ceb3de931e3.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/f3a123432445/ (stored 0%)',
#  '  adding: kaggle/working/output/f3a123432445/54be100fb1d3/ (stored 0%)',
#  '  adding: kaggle/working/output/f3a123432445/54be100fb1d3/982d490479ca.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/8a606a964b1d/ (stored 0%)',
#  '  adding: kaggle/working/output/8a606a964b1d/56cbe3430569/ (stored 0%)',
#  '  adding: kaggle/working/output/8a606a964b1d/56cbe3430569/010e677381f7.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/8cf883e963b2/ (stored 0%)',
#  '  adding: kaggle/working/output/8cf883e963b2/a3889d49b834/ (stored 0%)',
#  '  adding: kaggle/working/output/8cf883e963b2/a3889d49b834/fba14484d915.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/600ab69570f2/ (stored 0%)',
#  '  adding: kaggle/working/output/600ab69570f2/e032cc8a3841/ (stored 0%)',
#  '  adding: kaggle/working/output/600ab69570f2/e032cc8a3841/9206443f38f4.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/aa749b4d6cdd/ (stored 0%)',
#  '  adding: kaggle/working/output/aa749b4d6cdd/bcccc1537f0e/ (stored 0%)',
#  '  adding: kaggle/working/output/aa749b4d6cdd/bcccc1537f0e/0b9ceba31ef2.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/59289712b7a7/ (stored 0%)',
#  '  adding: kaggle/working/output/59289712b7a7/b6aba526030f/ (stored 0%)',
#  '  adding: kaggle/working/output/59289712b7a7/b6aba526030f/d91acd41cafa.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/2c1a30d2b9dc/ (stored 0%)',
#  '  adding: kaggle/working/output/2c1a30d2b9dc/0b74336e071b/ (stored 0%)',
#  '  adding: kaggle/working/output/2c1a30d2b9dc/0b74336e071b/8eb882164ef4.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/a19272b73379/ (stored 0%)',
#  '  adding: kaggle/working/output/a19272b73379/16858cab76b5/ (stored 0%)',
#  '  adding: kaggle/working/output/a19272b73379/16858cab76b5/fad1363c385b.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/2938b11fe3f2/ (stored 0%)',
#  '  adding: kaggle/working/output/2938b11fe3f2/1ea94b2e5817/ (stored 0%)',
#  '  adding: kaggle/working/output/2938b11fe3f2/1ea94b2e5817/d74b9368cbe5.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/9776469ed2a5/ (stored 0%)',
#  '  adding: kaggle/working/output/9776469ed2a5/3291080e8865/ (stored 0%)',
#  '  adding: kaggle/working/output/9776469ed2a5/3291080e8865/0b33282b08d8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/d129ac8188d6/ (stored 0%)',
#  '  adding: kaggle/working/output/d129ac8188d6/a185de24bd3b/ (stored 0%)',
#  '  adding: kaggle/working/output/d129ac8188d6/a185de24bd3b/f47a7274ffc6.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/959a145fac73/ (stored 0%)',
#  '  adding: kaggle/working/output/959a145fac73/1b1f202ef9b0/ (stored 0%)',
#  '  adding: kaggle/working/output/959a145fac73/1b1f202ef9b0/f1a67c1f073a.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/b36a47fb5f1f/ (stored 0%)',
#  '  adding: kaggle/working/output/b36a47fb5f1f/90cee363adb1/ (stored 0%)',
#  '  adding: kaggle/working/output/b36a47fb5f1f/90cee363adb1/0e8310f8b1a2.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/59e10fae4c81/ (stored 0%)',
#  '  adding: kaggle/working/output/59e10fae4c81/320e32ffc0e5/ (stored 0%)',
# ...
#  '  adding: kaggle/working/output/54a27efa3410/ (stored 0%)',
#  '  adding: kaggle/working/output/54a27efa3410/5c3897e44b96/ (stored 0%)',
#  '  adding: kaggle/working/output/54a27efa3410/5c3897e44b96/e3ab2d72cac2.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/08b5ac196fae/ (stored 0%)',
#  '  adding: kaggle/working/output/08b5ac196fae/f1866237dfbc/ (stored 0%)',
#  '  adding: kaggle/working/output/08b5ac196fae/f1866237dfbc/9ae7751f111a.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/381951fcbfd0/ (stored 0%)',
#  '  adding: kaggle/working/output/381951fcbfd0/bfc42321c637/ (stored 0%)',
#  '  adding: kaggle/working/output/381951fcbfd0/bfc42321c637/760b6875a1f2.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/3964a008403e/ (stored 0%)',
#  '  adding: kaggle/working/output/3964a008403e/387e97909a73/ (stored 0%)',
#  '  adding: kaggle/working/output/3964a008403e/387e97909a73/fda9216898b1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/837fc1ed550e/ (stored 0%)',
#  '  adding: kaggle/working/output/837fc1ed550e/c332ee9c4c3c/ (stored 0%)',
#  '  adding: kaggle/working/output/837fc1ed550e/c332ee9c4c3c/d3e9fb245247.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/aab3267c0c17/ (stored 0%)',
#  '  adding: kaggle/working/output/aab3267c0c17/398ebb73a5a2/ (stored 0%)',
#  '  adding: kaggle/working/output/aab3267c0c17/398ebb73a5a2/b9526de44654.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/afe34bf97c4a/ (stored 0%)',
#  '  adding: kaggle/working/output/afe34bf97c4a/275c898df7f4/ (stored 0%)',
#  '  adding: kaggle/working/output/afe34bf97c4a/275c898df7f4/4b310bbd3cb1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/afe34bf97c4a/a61b94bc345d/ (stored 0%)',
#  '  adding: kaggle/working/output/afe34bf97c4a/a61b94bc345d/b69412006842.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/e59ac8552f60/ (stored 0%)',
#  '  adding: kaggle/working/output/e59ac8552f60/4437aee10a1c/ (stored 0%)',
#  '  adding: kaggle/working/output/e59ac8552f60/4437aee10a1c/506dca9ef41f.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/8ceba80333df/ (stored 0%)',
#  '  adding: kaggle/working/output/8ceba80333df/854b325ae92f/ (stored 0%)',
#  '  adding: kaggle/working/output/8ceba80333df/854b325ae92f/d213cf9b4869.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/a4b311d1dc4b/ (stored 0%)',
#  '  adding: kaggle/working/output/a4b311d1dc4b/64eeb306f5e2/ (stored 0%)',
#  '  adding: kaggle/working/output/a4b311d1dc4b/64eeb306f5e2/b439e41975f1.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/b8544e55f55e/ (stored 0%)',
#  '  adding: kaggle/working/output/b8544e55f55e/89bfa275de72/ (stored 0%)',
#  '  adding: kaggle/working/output/b8544e55f55e/89bfa275de72/6df2d2ec8f31.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/68797cbf2957/ (stored 0%)',
#  '  adding: kaggle/working/output/68797cbf2957/be8d7ef44bcf/ (stored 0%)',
#  '  adding: kaggle/working/output/68797cbf2957/be8d7ef44bcf/dd2a5a29876f.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/7143ac3d6c02/ (stored 0%)',
#  '  adding: kaggle/working/output/7143ac3d6c02/93c57004c99a/ (stored 0%)',
#  '  adding: kaggle/working/output/7143ac3d6c02/93c57004c99a/095b28ad701c.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/508d6acdc4ce/ (stored 0%)',
#  '  adding: kaggle/working/output/508d6acdc4ce/0e820e137c98/ (stored 0%)',
#  '  adding: kaggle/working/output/508d6acdc4ce/0e820e137c98/28cd1f82f1be.jpg (deflated 3%)',
#  '  adding: kaggle/working/output/59e43e0b66a9/ (stored 0%)',
#  '  adding: kaggle/working/output/59e43e0b66a9/a074f8449c30/ (stored 0%)',
#  '  adding: kaggle/working/output/59e43e0b66a9/a074f8449c30/2d1ba4f1125a.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/14be42e4beee/ (stored 0%)',
#  '  adding: kaggle/working/output/14be42e4beee/a68e4ba3e851/ (stored 0%)',
#  '  adding: kaggle/working/output/14be42e4beee/a68e4ba3e851/2af4fdd6b125.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d9539ac29614/ (stored 0%)',
#  '  adding: kaggle/working/output/d9539ac29614/a72c7c6e2d1f/ (stored 0%)',
#  '  adding: kaggle/working/output/d9539ac29614/a72c7c6e2d1f/880c10b2c075.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/737a25e956f4/ (stored 0%)',
#  '  adding: kaggle/working/output/737a25e956f4/1e7a7f085972/ (stored 0%)',
#  '  adding: kaggle/working/output/737a25e956f4/1e7a7f085972/be47d4efb679.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/6fecf0039e87/ (stored 0%)',
#  '  adding: kaggle/working/output/6fecf0039e87/e18443a3fa39/ (stored 0%)',
#  '  adding: kaggle/working/output/6fecf0039e87/e18443a3fa39/76988ae210f1.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/6fecf0039e87/e01648fd5931/ (stored 0%)',
#  '  adding: kaggle/working/output/6fecf0039e87/e01648fd5931/88e7702b49c4.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/3865c0d08f85/ (stored 0%)',
#  '  adding: kaggle/working/output/3865c0d08f85/6751cf81e81c/ (stored 0%)',
#  '  adding: kaggle/working/output/3865c0d08f85/6751cf81e81c/6973c4f114b7.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/cfc48a3e03b9/ (stored 0%)',
#  '  adding: kaggle/working/output/cfc48a3e03b9/e1c80f2af761/ (stored 0%)',
#  '  adding: kaggle/working/output/cfc48a3e03b9/e1c80f2af761/e51b49a19853.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/4d4042629e59/ (stored 0%)',
#  '  adding: kaggle/working/output/4d4042629e59/15c8dc3428f8/ (stored 0%)',
#  '  adding: kaggle/working/output/4d4042629e59/15c8dc3428f8/5b2261258aa5.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/eb9dc561833d/ (stored 0%)',
#  '  adding: kaggle/working/output/eb9dc561833d/5b250e7bba4c/ (stored 0%)',
#  '  adding: kaggle/working/output/eb9dc561833d/5b250e7bba4c/0b49d75e3b51.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/22278d83c0ab/ (stored 0%)',
#  '  adding: kaggle/working/output/22278d83c0ab/07bdc4ab12b5/ (stored 0%)',
#  '  adding: kaggle/working/output/22278d83c0ab/07bdc4ab12b5/564e4f8c9746.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/66541affb82b/ (stored 0%)',
#  '  adding: kaggle/working/output/66541affb82b/f8d787bf1e72/ (stored 0%)',
#  '  adding: kaggle/working/output/66541affb82b/f8d787bf1e72/576d88aa052e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/0c9f6e26f5fc/ (stored 0%)',
#  '  adding: kaggle/working/output/0c9f6e26f5fc/cc6b5d0a3f39/ (stored 0%)',
#  '  adding: kaggle/working/output/0c9f6e26f5fc/cc6b5d0a3f39/483055c5b1dd.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/1a2cbb5c1a7f/ (stored 0%)',
#  '  adding: kaggle/working/output/1a2cbb5c1a7f/946e5c78cdfc/ (stored 0%)',
#  '  adding: kaggle/working/output/1a2cbb5c1a7f/946e5c78cdfc/6306eee379dc.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/c7d21e91ecb8/ (stored 0%)',
#  '  adding: kaggle/working/output/c7d21e91ecb8/cf22615948de/ (stored 0%)',
#  '  adding: kaggle/working/output/c7d21e91ecb8/cf22615948de/ad561049cfd8.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/0482ed7dda6e/ (stored 0%)',
#  '  adding: kaggle/working/output/0482ed7dda6e/985fb34c2856/ (stored 0%)',
#  '  adding: kaggle/working/output/0482ed7dda6e/985fb34c2856/0d2cb1c212ff.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/0a5b9e289c44/ (stored 0%)',
#  '  adding: kaggle/working/output/0a5b9e289c44/16e299fadd39/ (stored 0%)',
#  '  adding: kaggle/working/output/0a5b9e289c44/16e299fadd39/2f1ce67c8d80.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/0adfd8d6f010/ (stored 0%)',
#  '  adding: kaggle/working/output/0adfd8d6f010/b1dfe7a790f2/ (stored 0%)',
#  '  adding: kaggle/working/output/0adfd8d6f010/b1dfe7a790f2/be75ab9cecce.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/10c04ba1bd2b/ (stored 0%)',
#  '  adding: kaggle/working/output/10c04ba1bd2b/9368b02b515e/ (stored 0%)',
#  '  adding: kaggle/working/output/10c04ba1bd2b/9368b02b515e/124d0765c82a.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/72c48e3d0100/ (stored 0%)',
#  '  adding: kaggle/working/output/72c48e3d0100/303c071c56e7/ (stored 0%)',
#  '  adding: kaggle/working/output/72c48e3d0100/303c071c56e7/1ae1aca1fd0e.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/c58d3494fd01/ (stored 0%)',
#  '  adding: kaggle/working/output/c58d3494fd01/7bd3d8ca59e3/ (stored 0%)',
#  '  adding: kaggle/working/output/c58d3494fd01/7bd3d8ca59e3/7633b09ae491.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/110f748ac87d/ (stored 0%)',
#  '  adding: kaggle/working/output/110f748ac87d/556c180fac2c/ (stored 0%)',
#  '  adding: kaggle/working/output/110f748ac87d/556c180fac2c/a885755619ad.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/26b07f9e9e24/ (stored 0%)',
#  '  adding: kaggle/working/output/26b07f9e9e24/b9f9f6d826b1/ (stored 0%)',
#  '  adding: kaggle/working/output/26b07f9e9e24/b9f9f6d826b1/3a5a28071e03.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/eb25647982fe/ (stored 0%)',
#  '  adding: kaggle/working/output/eb25647982fe/767b60bc7e38/ (stored 0%)',
#  '  adding: kaggle/working/output/eb25647982fe/767b60bc7e38/bad16fab66e2.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/11b52fbe26a3/ (stored 0%)',
#  '  adding: kaggle/working/output/11b52fbe26a3/b7f109d014c3/ (stored 0%)',
#  '  adding: kaggle/working/output/11b52fbe26a3/b7f109d014c3/94db5ad07806.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/0833353809f6/ (stored 0%)',
#  '  adding: kaggle/working/output/0833353809f6/f5a22296f685/ (stored 0%)',
#  '  adding: kaggle/working/output/0833353809f6/f5a22296f685/cec9a538ac59.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/96991f19b1f9/ (stored 0%)',
#  '  adding: kaggle/working/output/96991f19b1f9/ee545a87cc40/ (stored 0%)',
#  '  adding: kaggle/working/output/96991f19b1f9/ee545a87cc40/a375ce0836a1.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/faaf89353e32/ (stored 0%)',
#  '  adding: kaggle/working/output/faaf89353e32/89e9cc59e908/ (stored 0%)',
#  '  adding: kaggle/working/output/faaf89353e32/89e9cc59e908/b431787c9f2f.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/168dddd3daa1/ (stored 0%)',
#  '  adding: kaggle/working/output/168dddd3daa1/b9b0ff906738/ (stored 0%)',
#  '  adding: kaggle/working/output/168dddd3daa1/b9b0ff906738/1b3d36c26846.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/d9ed94436325/ (stored 0%)',
#  '  adding: kaggle/working/output/d9ed94436325/c53eceb94fd3/ (stored 0%)',
#  '  adding: kaggle/working/output/d9ed94436325/c53eceb94fd3/2308e67bc9a8.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/512a9622ca0f/ (stored 0%)',
#  '  adding: kaggle/working/output/512a9622ca0f/3f5a056f8ba3/ (stored 0%)',
#  '  adding: kaggle/working/output/512a9622ca0f/3f5a056f8ba3/67abaa5570f0.jpg (deflated 4%)',
#  '  adding: kaggle/working/output/b9b8a810f2d0/ (stored 0%)',
#  '  adding: kaggle/working/output/b9b8a810f2d0/e39593002140/ (stored 0%)',
#  '  adding: kaggle/working/output/b9b8a810f2d0/e39593002140/e86e443c371b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/7282d136726d/ (stored 0%)',
#  '  adding: kaggle/working/output/7282d136726d/1355f43af590/ (stored 0%)',
#  '  adding: kaggle/working/output/7282d136726d/1355f43af590/c25217a1de28.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/91107b116bec/ (stored 0%)',
#  '  adding: kaggle/working/output/91107b116bec/3cc6240c321f/ (stored 0%)',
#  '  adding: kaggle/working/output/91107b116bec/3cc6240c321f/a650491c7276.jpg (deflated 7%)',
#  '  adding: kaggle/working/output/04fc265a693e/ (stored 0%)',
#  '  adding: kaggle/working/output/04fc265a693e/7f543014b4f0/ (stored 0%)',
#  '  adding: kaggle/working/output/04fc265a693e/7f543014b4f0/967482047b0c.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/08ee3bc2ae53/ (stored 0%)',
#  '  adding: kaggle/working/output/08ee3bc2ae53/b0ace722e2f8/ (stored 0%)',
#  '  adding: kaggle/working/output/08ee3bc2ae53/b0ace722e2f8/a064ae2fb018.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/69f1fef9ba01/ (stored 0%)',
#  '  adding: kaggle/working/output/69f1fef9ba01/393493d2ae4f/ (stored 0%)',
#  '  adding: kaggle/working/output/69f1fef9ba01/393493d2ae4f/3287bfcd205c.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/784afbafee30/ (stored 0%)',
#  '  adding: kaggle/working/output/784afbafee30/2734dce96fcb/ (stored 0%)',
#  '  adding: kaggle/working/output/784afbafee30/2734dce96fcb/57bf106a9e2e.jpg (stored 0%)',
#  '  adding: kaggle/working/output/784afbafee30/54a7b3303150/ (stored 0%)',
#  '  adding: kaggle/working/output/784afbafee30/54a7b3303150/7f11df4026e3.jpg (stored 0%)',
#  '  adding: kaggle/working/output/23da56e1750a/ (stored 0%)',
#  '  adding: kaggle/working/output/23da56e1750a/d2ada923e7f7/ (stored 0%)',
#  '  adding: kaggle/working/output/23da56e1750a/d2ada923e7f7/374fe1b05022.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/537d1ce14277/ (stored 0%)',
#  '  adding: kaggle/working/output/537d1ce14277/41c592c82595/ (stored 0%)',
#  '  adding: kaggle/working/output/537d1ce14277/41c592c82595/e22c7a599e4c.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/4e3671f1dbf8/ (stored 0%)',
#  '  adding: kaggle/working/output/4e3671f1dbf8/fc02776b6afb/ (stored 0%)',
#  '  adding: kaggle/working/output/4e3671f1dbf8/fc02776b6afb/7ab08582b201.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/1a2eaf44d296/ (stored 0%)',
#  '  adding: kaggle/working/output/1a2eaf44d296/de39acade51d/ (stored 0%)',
#  '  adding: kaggle/working/output/1a2eaf44d296/de39acade51d/7a64a3fcbfa7.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/e4f280b01af5/ (stored 0%)',
#  '  adding: kaggle/working/output/e4f280b01af5/23a8177c9db1/ (stored 0%)',
#  '  adding: kaggle/working/output/e4f280b01af5/23a8177c9db1/4d647a4df4a8.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/1ed21574ae51/ (stored 0%)',
#  '  adding: kaggle/working/output/1ed21574ae51/929240fbc9b2/ (stored 0%)',
#  '  adding: kaggle/working/output/1ed21574ae51/929240fbc9b2/70fcced4ab9a.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/7f7ef67844a4/ (stored 0%)',
#  '  adding: kaggle/working/output/7f7ef67844a4/b6eeed1fa6e8/ (stored 0%)',
#  '  adding: kaggle/working/output/7f7ef67844a4/b6eeed1fa6e8/e616156054ac.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/e36dac4d5aca/ (stored 0%)',
#  '  adding: kaggle/working/output/e36dac4d5aca/5c75ee68c4a0/ (stored 0%)',
#  '  adding: kaggle/working/output/e36dac4d5aca/5c75ee68c4a0/023b985092de.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/422689777b34/ (stored 0%)',
#  '  adding: kaggle/working/output/422689777b34/67f56ec3932c/ (stored 0%)',
#  '  adding: kaggle/working/output/422689777b34/67f56ec3932c/54f658731652.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/2a1768cea4ae/ (stored 0%)',
#  '  adding: kaggle/working/output/2a1768cea4ae/15e1ae5503c5/ (stored 0%)',
#  '  adding: kaggle/working/output/2a1768cea4ae/15e1ae5503c5/b958a76ecf24.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/4cd37e041b4c/ (stored 0%)',
#  '  adding: kaggle/working/output/4cd37e041b4c/cddbd3fedbe5/ (stored 0%)',
#  '  adding: kaggle/working/output/4cd37e041b4c/cddbd3fedbe5/9d7faec50cfa.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/7b10c52613de/ (stored 0%)',
#  '  adding: kaggle/working/output/7b10c52613de/9a8c8465429f/ (stored 0%)',
#  '  adding: kaggle/working/output/7b10c52613de/9a8c8465429f/973db0636a3b.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/18dd691d5dc5/ (stored 0%)',
#  '  adding: kaggle/working/output/18dd691d5dc5/73d8466a8134/ (stored 0%)',
#  '  adding: kaggle/working/output/18dd691d5dc5/73d8466a8134/0fc37fb1363a.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/67248a9a20b2/ (stored 0%)',
#  '  adding: kaggle/working/output/67248a9a20b2/909729c23830/ (stored 0%)',
#  '  adding: kaggle/working/output/67248a9a20b2/909729c23830/8eee4b098b75.jpg (deflated 0%)',
#  '  adding: kaggle/working/output/2d430161fb34/ (stored 0%)',
#  '  adding: kaggle/working/output/2d430161fb34/23f61645191d/ (stored 0%)',
#  '  adding: kaggle/working/output/2d430161fb34/23f61645191d/c7c8d03d68cb.jpg (deflated 1%)',
#  '  adding: kaggle/working/output/619a7e7565ff/ (stored 0%)',
#  '  adding: kaggle/working/output/619a7e7565ff/9296be7da020/ (stored 0%)',
#  '  adding: kaggle/working/output/619a7e7565ff/9296be7da020/9a5d49cc13dc.jpg (deflated 2%)',
#  '  adding: kaggle/working/output/d191addc1610/ (stored 0%)',
#  ...]
